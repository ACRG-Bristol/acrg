# %%
# %run flux_output_format.py
# Out:
# Sampling: [bc, sigma, x, ymod, ymodbc]

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (probs: 4, nsite: 30, time: 168)
# Coordinates:
#   * probs        (probs) float64 0.025 0.159 0.841 0.975
#   * nsite        (nsite) float64 0.0 1.0 2.0 3.0 4.0 ... 26.0 27.0 28.0 29.0
#   * time         (time) int64 1612137600 1612152000 ... 1614528000 1614542400
# Data variables: (12/13)
#     Yobs         (nsite, time) float64 1.978e-06 1.977e-06 1.978e-06 ... nan nan
#     uYobs        (nsite, time) float64 5.214e-10 6.366e-11 9.982e-10 ... nan nan
#     Yapriori     (nsite, time) float64 1.978e-06 1.976e-06 1.977e-06 ... nan nan
#     Yapost       (nsite, time) float64 1.992e-06 1.989e-06 1.991e-06 ... nan nan
#     YaprioriBC   (nsite, time) float64 1.969e-06 1.969e-06 1.969e-06 ... nan nan
#     YapostBC     (nsite, time) float64 1.975e-06 1.974e-06 1.975e-06 ... nan nan
#     ...           ...
#     qYmod        (nsite, time, probs) float64 1.783e-06 1.873e-06 ... nan nan
# ...

# %%
ds.to_netcdf("conc_test.nc", engine="netcdf4")

# %%
# !ncdump -c conc_test.nc
# Out:
# netcdf conc_test {
# dimensions:
# 	probs = 4 ;
# 	nsite = 30 ;
# 	time = 168 ;
# variables:
# 	double probs(probs) ;
# 		probs:_FillValue = NaN ;
# 		probs:units = "-" ;
# 		probs:longname = "probability" ;
# 	double nsite(nsite) ;
# 		nsite:_FillValue = NaN ;
# 	double Yobs(nsite, time) ;
# 		Yobs:_FillValue = NaN ;
# 		Yobs:units = "mol/mol" ;
# 		Yobs:longname = "observed_mol_fraction" ;
# 	double uYobs(nsite, time) ;
# 		uYobs:_FillValue = NaN ;
# 		uYobs:units = "mol/mol" ;
# 		uYobs:longname = "uncertainty_of_observed_mol_fraction" ;
# 	double Yapriori(nsite, time) ;
# 		Yapriori:_FillValue = NaN ;
# 		Yapriori:units = "mol/mol" ;
# 		Yapriori:longname = "apriori_simulated_mole_fraction" ;
# 	double Yapost(nsite, time) ;
# 		Yapost:_FillValue = NaN ;
# 		Yapost:units = "mol/mol" ;
# 		Yapost:longname = "aposteriori_simulated_mole_fraction" ;
# 	double YaprioriBC(nsite, time) ;
# 		YaprioriBC:_FillValue = NaN ;
# 		YaprioriBC:units = "mol/mol" ;
# ...
